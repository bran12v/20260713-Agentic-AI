# %%
# !pip install azure-ai-textanalytics==5.2.0
# Out:
# Requirement already satisfied: azure-ai-textanalytics==5.2.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (5.2.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from azure-ai-textanalytics==5.2.0) (1.41.0)
# Requirement already satisfied: msrest>=0.7.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from azure-ai-textanalytics==5.2.0) (0.7.1)
# Requirement already satisfied: azure-common~=1.1 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from azure-ai-textanalytics==5.2.0) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from azure-ai-textanalytics==5.2.0) (4.16.0)
# Requirement already satisfied: requests>=2.21.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics==5.2.0) (2.34.2)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from msrest>=0.7.0->azure-ai-textanalytics==5.2.0) (2026.6.17)
# Requirement already satisfied: isodate>=0.6.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from msrest>=0.7.0->azure-ai-textanalytics==5.2.0) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from msrest>=0.7.0->azure-ai-textanalytics==5.2.0) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics==5.2.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics==5.2.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics==5.2.0) (2.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\Users\BrandonVanek\Desktop\AIDev\20260713 Guidehouse\support-platform\support-api\.venv\Lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.0->azure-ai-textanalytics==5.2.0) (3.3.1)

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential
from dotenv import load_dotenv
from pathlib import Path
import os

# %%
load_dotenv(Path.cwd().parent / ".env")
# Out:
# True

# %%
endpoint = os.environ.get("AZURE_LANGUAGE_ENDPOINT")
api_key = os.environ.get("AZURE_LANGUAGE_KEY")

# %%
# Authenticate the client using your key and endpoint
def authenticate_client():
    ta_credential = AzureKeyCredential(api_key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint,
            credential=ta_credential)
    return text_analytics_client

client = authenticate_client()

# %%
# Example method for detecting the language of text
def language_detection_example(client):
    try:
        documents = ["这是中文."]
        response = client.detect_language(documents = documents, country_hint = 'us')[0]
        print("Language: ", response.primary_language.name)

    except Exception as err:
        print("Encountered exception. {}".format(err))

# %%
response = language_detection_example(client)
# Out:
# Language:  Chinese_Simplified
